# %%
import pandas as pd

# %%
import glob
import pandas as pd

# Busca automáticamente dónde está el archivo en tus subcarpetas
archivos = glob.glob("**/laptop_price.csv", recursive=True)

if archivos:
  ruta_archivo = archivos[0]
  # Carga segura con encoding para evitar problemas de tildes o caracteres especiales
  df_laptops = pd.read_csv(ruta_archivo, encoding="latin-1")
  # Muestra las primeras 3 filas
  display(df_laptops.head(3))
else:
  print(
      "❌ No se encontró el archivo 'laptop_price.csv'. Asegúrate de que"
      " esté en tu repositorio."
  )
# Out:
# ❌ No se encontró el archivo 'laptop_price.csv'. Asegúrate de que esté en tu repositorio.

# %%
df_laptops.head(3)

# %% [markdown]
# # Ejercicio

# %%
# crear un array basado en el tamaño de pantala ("screen size" mayor a 15 es 'Big' y menor o igual a 15 es 'Small')

# %%
# añadir a nueva columna

# %%
# mostrar primeras 5 filas

# %%
# contar valores en columna screen_size
