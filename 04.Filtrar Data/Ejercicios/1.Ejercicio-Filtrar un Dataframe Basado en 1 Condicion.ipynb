# %%
import pandas as pd

# %%
import glob

# Busca el archivo en cualquier subcarpeta del repositorio
encontrados = glob.glob('**/laptop_price.csv', recursive=True)
print('Rutas encontradas:', encontrados)
# Out:
# Rutas encontradas: []

# %%
import glob
import pandas as pd

# Busca automáticamente el archivo en cualquier subcarpeta del repositorio
archivos = glob.glob("**/laptop_price.csv", recursive=True)

if archivos:
  ruta_real = archivos[0]
  print(f"¡Archivo encontrado! Cargando desde: {ruta_real}")

  # Carga segura con latin-1 para evitar errores de tildes o caracteres especiales
  df_laptops = pd.read_csv(ruta_real, encoding="latin-1")

  # Muestra las primeras 3 filas
  display(df_laptops.head(3))
else:
  print("No se encontró 'laptop_price.csv'. Verifica que esté en la carpeta.")
# Out:
# No se encontró 'laptop_price.csv'. Verifica que esté en la carpeta.

# %% [markdown]
# ## Ejercicio 1

# %%
# encontrar que filar no tienen "HP" en la columna "Company"

# %%
# filtrar dataframe basado en la condicion

# %% [markdown]
# ## Ejercicio 2

# %%
# encontrar laptop con precio arriba de 2000 euros
